# %%
import pandas as pd
from imblearn.over_sampling import SMOTE

# for reproducibility purposes
seed = 100
# SMOTE number of neighbors
k = 1

df = pd.read_csv("Dataset.csv")
df.describe()
# Out:
#        Age of Subject  Time spent on Online Class  Time spent on self study  \
# count     1182.000000                 1182.000000               1182.000000
# mean        20.165821                    3.208841                  2.875212
# std          5.516467                    2.101756                  1.995618
# min          7.000000                    0.000000                  0.000000
# 25%         17.000000                    2.000000                  2.000000
# 50%         20.000000                    3.000000                  2.000000
# 75%         21.000000                    5.000000                  4.000000
# max         59.000000                   10.000000                 10.000000
#
#        Time_spent_on_fitness  Time_spent_on_sleep  Time_spent_on_social_media  \
# count            1183.000000          1183.000000                 1182.000000
# mean                0.765385             7.871344                    2.365694
# std                 0.724300             1.615083                    1.767336
# min                 0.000000             4.000000                    0.000000
# 25%                 0.000000             7.000000                    1.000000
# 50%                 1.000000             8.000000                    2.000000
# 75%                 1.000000             9.000000                    3.000000
# max                 5.000000            15.000000                   10.000000
#
#        Number of meals per day  Good_Mental_Health  Bad Mental Health  \
# count              1182.000000                 1.0                1.0
# mean                  2.917936                76.0             1106.0
# std                   0.828698                 NaN                NaN
# min                   1.000000                76.0             1106.0
# 25%                   2.000000                76.0             1106.0
# 50%                   3.000000                76.0             1106.0
# 75%                   3.000000                76.0             1106.0
# max                   8.000000                76.0             1106.0
#
#        Good Performance  Standard Fitness  Standard Sleep  \
# count               1.0               1.0             1.0
# mean               25.0             605.0           785.0
# std                 NaN               NaN             NaN
# min                25.0             605.0           785.0
# 25%                25.0             605.0           785.0
# 50%                25.0             605.0           785.0
# 75%                25.0             605.0           785.0
# max                25.0             605.0           785.0
#
#        Standard Watching TV  Standard Using Social Media
# count                   1.0                          1.0
# mean                 1075.0                         80.0
# std                     NaN                          NaN
# min                  1075.0                         80.0
# 25%                  1075.0                         80.0
# 50%                  1075.0                         80.0
# 75%                  1075.0                         80.0
# max                  1075.0                         80.0
