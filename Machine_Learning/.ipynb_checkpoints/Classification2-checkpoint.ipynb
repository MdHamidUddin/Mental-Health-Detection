# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn import preprocessing
from sklearn import metrics
from sklearn import utils
import warnings 
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
# for reproducibility purposes
seed = 100
# SMOTE number of neighbors
k = 1
df = pd.read_csv("Dataset3.csv")
#df.pop("Mental_Health")
df = df.dropna()
correlation_matrix = df.corr().round(2)
mask = np.zeros_like(correlation_matrix)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize = (10, 5))
sns.heatmap(data=correlation_matrix, annot=True, mask=mask);
del df["ID"]
df.to_csv('exp.csv', index=False, encoding='utf-8')
df.describe()
# Out:
#        Age_of_Subject  Time_spent_on_Online_Class  \
# count     1182.000000                 1182.000000
# mean        20.165821                    3.208841
# std          5.516467                    2.101756
# min          7.000000                    0.000000
# 25%         17.000000                    2.000000
# 50%         20.000000                    3.000000
# 75%         21.000000                    5.000000
# max         59.000000                   10.000000
#
#        Rating_of_Online_Class_experience  Medium_for_online_class  \
# count                        1182.000000              1182.000000
# mean                            2.845178                 1.521997
# std                             1.204236                 0.781306
# min                             0.000000                 0.000000
# 25%                             2.000000                 1.000000
# 50%                             3.000000                 1.000000
# 75%                             4.000000                 2.000000
# max                             5.000000                 7.000000
#
#        Time_spent_on_self_study  Time_spent_on_fitness  Time_spent_on_sleep  \
# count               1182.000000            1182.000000          1182.000000
# mean                   2.875212               0.765821             7.871235
# std                    1.995618               0.724451             1.615762
# min                    0.000000               0.000000             4.000000
# 25%                    2.000000               0.000000             7.000000
# 50%                    2.000000               1.000000             8.000000
# 75%                    4.000000               1.000000             9.000000
# max                   10.000000               5.000000            15.000000
#
#        Time_spent_on_social_media  Prefered_social_media_platform  \
# count                 1182.000000                     1182.000000
# mean                     2.365694                        5.483080
# std                      1.767336                        1.755398
# min                      0.000000                        0.000000
# 25%                      1.000000                        5.000000
# 50%                      2.000000                        6.000000
# 75%                      3.000000                        7.000000
# max                     10.000000                       13.000000
#
#        Number_of_meals_per_day  Change_in_your_weight  \
# count              1182.000000            1182.000000
# mean                  2.917936               0.724196
# std                   0.828698               0.744206
# min                   1.000000               0.000000
# 25%                   2.000000               0.000000
# 50%                   3.000000               1.000000
# 75%                   3.000000               1.000000
# max                   8.000000               2.000000
#
#        Health_issue_during_lockdown  Time_utilized  Family_Relation  \
# count                   1182.000000    1182.000000      1182.000000
# mean                       0.136210       0.485618         0.703046
# std                        0.343156       0.500005         0.457110
# min                        0.000000       0.000000         0.000000
# 25%                        0.000000       0.000000         0.000000
# 50%                        0.000000       0.000000         1.000000
# 75%                        0.000000       1.000000         1.000000
# max                        1.000000       1.000000         1.000000
#
#        Mental_Health
# count    1182.000000
# mean        0.608291
# std         0.488339
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
# make a new df made of all the columns, except the target class
X = df[['Time_spent_on_Online_Class', 'Time_spent_on_self_study', 'Time_utilized']]
y = df['Time_spent_on_social_media']
y = y.astype(int)
sm = SMOTE(sampling_strategy='auto', k_neighbors=k, random_state=seed)
X_res, y_res = sm.fit_resample(X, y)


df6 = pd.concat([pd.DataFrame(X_res), pd.DataFrame(y_res)], axis=1)

df6.to_csv('exp_smoted.csv', index=False, encoding='utf-8')

# %%
df1 = pd.read_csv("dataset3.csv")
df1 = df1.sample(1150)
plt.figure(figsize = (10, 5))
sns.countplot(df1['Time_spent_on_social_media'])
plt.show()

# %%
df2 = pd.read_csv("exp_smoted.csv")
df2 = df2.dropna()
df2["Time_spent_on_social_media"]
df2.Time_spent_on_social_media.value_counts()
df2.describe()
# Out:
#        Time_spent_on_Online_Class  Time_spent_on_self_study  Time_utilized  \
# count                 3949.000000               3949.000000    3949.000000
# mean                     3.087887                  2.527482       0.304887
# std                      2.176495                  1.794338       0.460418
# min                      0.000000                  0.000000       0.000000
# 25%                      1.460900                  1.102027       0.000000
# 50%                      3.000000                  2.000000       0.000000
# 75%                      4.369835                  3.450069       1.000000
# max                     10.000000                 10.000000       1.000000
#
#        Time_spent_on_social_media
# count                 3949.000000
# mean                     5.000000
# std                      3.162678
# min                      0.000000
# 25%                      2.000000
# 50%                      5.000000
# 75%                      8.000000
# max                     10.000000

# %%
df1 = pd.read_csv("exp_smoted.csv")
df1 = df1.sample(1150)
plt.figure(figsize = (10, 5))
sns.countplot(df1['Time_spent_on_social_media'])
plt.show()

# %%
df1 = pd.read_csv("dataset3.csv")
df1 = df1.sample(1150)
plt.figure(figsize = (10, 5))
sns.countplot(df1['Time_spent_on_social_media'])
plt.show()

# %%
df1 = pd.read_csv("dataset3.csv")
df1 = df1.sample(1150)
plt.figure(figsize = (10, 5))
sns.countplot(df1['Time_spent_on_fitness'])
plt.show()

# %%
# make a new df made of all the columns, except the target class
X = df[['Number_of_meals_per_day','Change_in_your_weight','Time_spent_on_Online_Class', 'Time_spent_on_self_study', 'Time_utilized']]
y = df['Time_spent_on_social_media']
y = y.astype(int)
X = X.astype(int)
sm = SMOTE(sampling_strategy='auto', k_neighbors=k, random_state=seed)
X_res, y_res = sm.fit_resample(X, y)
df4 = pd.concat([pd.DataFrame(X_res), pd.DataFrame(y_res)], axis=1)
df4.to_csv('fitness_smoted.csv', index=False, encoding='utf-8')

# %%
df.describe()
# Out:
#        Age_of_Subject  Time_spent_on_Online_Class  \
# count     1182.000000                 1182.000000
# mean        20.165821                    3.208841
# std          5.516467                    2.101756
# min          7.000000                    0.000000
# 25%         17.000000                    2.000000
# 50%         20.000000                    3.000000
# 75%         21.000000                    5.000000
# max         59.000000                   10.000000
#
#        Rating_of_Online_Class_experience  Medium_for_online_class  \
# count                        1182.000000              1182.000000
# mean                            2.845178                 1.521997
# std                             1.204236                 0.781306
# min                             0.000000                 0.000000
# 25%                             2.000000                 1.000000
# 50%                             3.000000                 1.000000
# 75%                             4.000000                 2.000000
# max                             5.000000                 7.000000
#
#        Time_spent_on_self_study  Time_spent_on_fitness  Time_spent_on_sleep  \
# count               1182.000000            1182.000000          1182.000000
# mean                   2.875212               0.765821             7.871235
# std                    1.995618               0.724451             1.615762
# min                    0.000000               0.000000             4.000000
# 25%                    2.000000               0.000000             7.000000
# 50%                    2.000000               1.000000             8.000000
# 75%                    4.000000               1.000000             9.000000
# max                   10.000000               5.000000            15.000000
#
#        Time_spent_on_social_media  Prefered_social_media_platform  \
# count                 1182.000000                     1182.000000
# mean                     2.365694                        5.483080
# std                      1.767336                        1.755398
# min                      0.000000                        0.000000
# 25%                      1.000000                        5.000000
# 50%                      2.000000                        6.000000
# 75%                      3.000000                        7.000000
# max                     10.000000                       13.000000
#
#        Number_of_meals_per_day  Change_in_your_weight  \
# count              1182.000000            1182.000000
# mean                  2.917936               0.724196
# std                   0.828698               0.744206
# min                   1.000000               0.000000
# 25%                   2.000000               0.000000
# 50%                   3.000000               1.000000
# 75%                   3.000000               1.000000
# max                   8.000000               2.000000
#
#        Health_issue_during_lockdown  Time_utilized  Family_Relation  \
# count                   1182.000000    1182.000000      1182.000000
# mean                       0.136210       0.485618         0.703046
# std                        0.343156       0.500005         0.457110
# min                        0.000000       0.000000         0.000000
# 25%                        0.000000       0.000000         0.000000
# 50%                        0.000000       0.000000         1.000000
# 75%                        0.000000       1.000000         1.000000
# max                        1.000000       1.000000         1.000000
#
#        Mental_Health
# count    1182.000000
# mean        0.608291
# std         0.488339
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
df.groupby("Time_spent_on_fitness").size()
# Out:
# Time_spent_on_fitness
# 0.00    419
# 0.25      6
# 0.30      5
# 0.50     53
# 0.60      2
# 1.00    550
# 2.00    119
# 2.50      1
# 3.00     25
# 4.00      1
# 5.00      1
# dtype: int64

# %%
df = df[df.Time_spent_on_fitness != 2.50]
df = df[df.Time_spent_on_fitness != 4.00]
df = df[df.Time_spent_on_fitness != 5.00]

# %%
df.groupby("Time_spent_on_fitness").size()
# Out:
# Time_spent_on_fitness
# 0.00    419
# 0.25      6
# 0.30      5
# 0.50     53
# 0.60      2
# 1.00    550
# 2.00    119
# 3.00     25
# dtype: int64

# %%
X = df[['Number_of_meals_per_day', 'Time_utilized']]
y = df['Time_spent_on_fitness']
y = y.astype(int)
X = X.astype(int)
sm = SMOTE(sampling_strategy='auto', k_neighbors=k, random_state=seed)
X_res, y_res = sm.fit_resample(X, y)
df4 = pd.concat([pd.DataFrame(X_res), pd.DataFrame(y_res)], axis=1)
df4.to_csv('fitness_smoted.csv', index=False, encoding='utf-8')

# %%
df1 = pd.read_csv("fitness_smoted.csv")
plt.figure(figsize = (10,5))
sns.countplot(df1['Time_spent_on_fitness'])
plt.show()

# %%
df.describe()
# Out:
#        Age_of_Subject  Time_spent_on_Online_Class  \
# count     1179.000000                 1179.000000
# mean        20.167091                    3.209372
# std          5.522456                    2.100771
# min          7.000000                    0.000000
# 25%         17.000000                    2.000000
# 50%         20.000000                    3.000000
# 75%         21.000000                    5.000000
# max         59.000000                   10.000000
#
#        Rating_of_Online_Class_experience  Medium_for_online_class  \
# count                        1179.000000              1179.000000
# mean                            2.844784                 1.519084
# std                             1.205743                 0.771038
# min                             0.000000                 0.000000
# 25%                             2.000000                 1.000000
# 50%                             3.000000                 1.000000
# 75%                             4.000000                 2.000000
# max                             5.000000                 7.000000
#
#        Time_spent_on_self_study  Time_spent_on_fitness  Time_spent_on_sleep  \
# count               1179.000000            1179.000000          1179.000000
# mean                   2.870653               0.758015             7.872604
# std                    1.985304               0.706721             1.616890
# min                    0.000000               0.000000             4.000000
# 25%                    2.000000               0.000000             7.000000
# 50%                    2.000000               1.000000             8.000000
# 75%                    4.000000               1.000000             9.000000
# max                   10.000000               3.000000            15.000000
#
#        Time_spent_on_social_media  Prefered_social_media_platform  \
# count                 1179.000000                     1179.000000
# mean                     2.361111                        5.484309
# std                      1.754670                        1.754078
# min                      0.000000                        0.000000
# 25%                      1.000000                        5.000000
# 50%                      2.000000                        6.000000
# 75%                      3.000000                        7.000000
# max                     10.000000                       13.000000
#
#        Number_of_meals_per_day  Change_in_your_weight  \
# count              1179.000000            1179.000000
# mean                  2.914334               0.724343
# std                   0.821169               0.743627
# min                   1.000000               0.000000
# 25%                   2.000000               0.000000
# 50%                   3.000000               1.000000
# 75%                   3.000000               1.000000
# max                   8.000000               2.000000
#
#        Health_issue_during_lockdown  Time_utilized  Family_Relation  \
# count                   1179.000000    1179.000000      1179.000000
# mean                       0.136556       0.485157         0.702290
# std                        0.343524       0.499992         0.457445
# min                        0.000000       0.000000         0.000000
# 25%                        0.000000       0.000000         0.000000
# 50%                        0.000000       0.000000         1.000000
# 75%                        0.000000       1.000000         1.000000
# max                        1.000000       1.000000         1.000000
#
#        Mental_Health
# count    1179.000000
# mean        0.608142
# std         0.488372
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
X = df[['Age_of_Subject','Time_spent_on_Online_Class','Rating_of_Online_Class_experience','Medium_for_online_class','Time_spent_on_self_study','Time_spent_on_fitness','Time_spent_on_sleep','Prefered_social_media_platform', 'Number_of_meals_per_day','Change_in_your_weight','Health_issue_during_lockdown','Time_utilized','Family_Relation','Mental_Health']]
y = df['Time_spent_on_social_media']
y = y.astype(int)
#X = X.astype(int)
sm = SMOTE(sampling_strategy='auto', k_neighbors=k, random_state=seed)
X_res, y_res = sm.fit_resample(X, y)
df4 = pd.concat([pd.DataFrame(X_res), pd.DataFrame(y_res)], axis=1)
df4.to_csv('Final.csv', index=False, encoding='utf-8')

# %%
df1 = pd.read_csv("Final.csv")
plt.figure(figsize = (10, 5))
sns.countplot(df1['Mental_Health'])
plt.show()

# %%
X = df1[['Age_of_Subject','Time_spent_on_Online_Class','Rating_of_Online_Class_experience','Medium_for_online_class','Time_spent_on_self_study','Time_spent_on_fitness','Time_spent_on_sleep','Time_spent_on_social_media','Prefered_social_media_platform', 'Number_of_meals_per_day','Change_in_your_weight','Health_issue_during_lockdown','Time_utilized','Family_Relation']]
y = df1['Mental_Health']
y = y.astype(int)
#X = X.astype(int)
sm = SMOTE(sampling_strategy='auto', k_neighbors=k, random_state=seed)
X_res, y_res = sm.fit_resample(X, y)
df4 = pd.concat([pd.DataFrame(X_res), pd.DataFrame(y_res)], axis=1)
df4.to_csv('Final1.csv', index=False, encoding='utf-8')

# %%
df1 = pd.read_csv("Final1.csv")

plt.figure(figsize = (10, 5))
sns.countplot(df1['Mental_Health'])
plt.show()

# %%
#for x in df1.index:
   # if df1.loc[x, "Time_spent_on_TV"] == " ":
      #  df1.loc[x, "Time_spent_on_TV"] = 0
       # print("hello")

#df1["Time_spent_on_TV"] = df1["Time_spent_on_TV"].astype(float)

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5906 entries, 0 to 5905
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age_of_Subject                     5906 non-null   int64
#  1   Time_spent_on_Online_Class         5906 non-null   float64
#  2   Rating_of_Online_Class_experience  5906 non-null   int64
#  3   Medium_for_online_class            5906 non-null   int64
#  4   Time_spent_on_self_study           5906 non-null   float64
#  5   Time_spent_on_fitness              5906 non-null   float64
#  6   Time_spent_on_sleep                5906 non-null   float64
#  7   Time_spent_on_social_media         5906 non-null   int64
#  8   Prefered_social_media_platform     5906 non-null   int64
#  9   Number_of_meals_per_day            5906 non-null   int64
#  10  Change_in_your_weight              5906 non-null   int64
#  11  Health_issue_during_lockdown       5906 non-null   int64
#  12  Time_utilized                      5906 non-null   int64
#  13  Family_Relation                    5906 non-null   int64
#  14  Mental_Health                      5906 non-null   int64
# dtypes: float64(4), int64(11)
# memory usage: 692.2 KB

# %%
X, y = df1.loc[:,df1.columns!='Mental_Health'], df1['Mental_Health']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)
print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)
print("y_train shape: ", y_train.shape)
print("y_test shape: ", y_test.shape)
# Out:
# X_train shape:  (5315, 14)
# X_test shape:  (591, 14)
# y_train shape:  (5315,)
# y_test shape:  (591,)

# %%
from sklearn import svm #for Support Vector Machine (SVM) Algorithm
model_svm = svm.SVC() #select the algorithm
model_svm.fit(X_train, y_train) #train the model with the training dataset
y_prediction_svm = model_svm.predict(X_test) # pass the testing data to the trained model
pred_1=model_svm.predict(X_test)
con_mat = confusion_matrix(y_test, pred_1)
# checking the accuracy of the algorithm. 
# by comparing predicted output by the model and the actual output
score_svm = metrics.accuracy_score(y_prediction_svm, y_test).round(4)
clf_report = classification_report(y_test, pred_1)
print("---------------------------------")
print('The accuracy of the SVM is: {}'.format(score_svm))
print("---------------------------------")
print(f"Confusion Matrix : \n{con_mat}")
print(f"Classification Report : \n{clf_report}")
# save the accuracy score
score = set()
score.add(('SVM', score_svm))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c99e143007ea> in <module>
#       4 y_prediction_svm = model_svm.predict(X_test) # pass the testing data to the trained model
#       5 pred_1=model_svm.predict(X_test)
# ----> 6 con_mat = confusion_matrix(y_test, pred_1)
#       7 # checking the accuracy of the algorithm.
#       8 # by comparing predicted output by the model and the actual output
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier #for using Decision Tree Algoithm
model_dt = DecisionTreeClassifier(random_state=4)
model_dt.fit(X_train, y_train) #train the model with the training dataset
y_prediction_dt = model_dt.predict(X_test) #pass the testing data to the trained model
pred_2=model_dt.predict(X_test)
con_mat = confusion_matrix(y_test, pred_2)
# checking the accuracy of the algorithm. 
# by comparing predicted output by the model and the actual output
score_dt = metrics.accuracy_score(y_prediction_dt, y_test).round(4)
clf_report = classification_report(y_test, pred_2)
print("---------------------------------")
print('The accuracy of the DT is: {}'.format(score_dt))
print("---------------------------------")
print(f"Confusion Matrix : \n{con_mat}")
print(f"Classification Report : \n{clf_report}")
# save the accuracy score
score.add(('DT', score_dt))

# %%
# importing the necessary package to use the classification algorithm
from sklearn.neighbors import KNeighborsClassifier # for K nearest neighbours
#from sklearn.linear_model import LogisticRegression # for Logistic Regression algorithm
model_knn = KNeighborsClassifier(n_neighbors=3) # 3 neighbours for putting the new data into a class
model_knn.fit(X_train, y_train) #train the model with the training dataset
y_prediction_knn = model_knn.predict(X_test) #pass the testing data to the trained model
pred_3=model_knn.predict(X_test)
con_mat = confusion_matrix(y_test, pred_3)
# checking the accuracy of the algorithm. 
# by comparing predicted output by the model and the actual output
score_knn = metrics.accuracy_score(y_prediction_knn, y_test).round(4)
clf_report = classification_report(y_test, pred_3)
print("---------------------------------")
print('The accuracy of the KNN is: {}'.format(score_knn))
print("---------------------------------")
print(f"Confusion Matrix : \n{con_mat}")
print(f"Classification Report : \n{clf_report}")


# save the accuracy score
score.add(('KNN', score_knn))

# %%
# importing the necessary package to use the classification algorithm
from sklearn.linear_model import LogisticRegression # for Logistic Regression algorithm
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train) #train the model with the training dataset
y_prediction_lr = model_lr.predict(X_test) #pass the testing data to the trained model
# checking the accuracy of the algorithm. 
# by comparing predicted output by the model and the actual output

score_lr = metrics.accuracy_score(y_prediction_lr, y_test).round(4)
pred_4=model_dt.predict(X_test)
con_mat = confusion_matrix(y_test, pred_4)

clf_report = classification_report(y_test, pred_4)
print("---------------------------------")
print('The accuracy of the LR is: {}'.format(score_lr))
print("---------------------------------")
print(f"Confusion Matrix : \n{con_mat}")
print(f"Classification Report : \n{clf_report}")
# save the accuracy score
score.add(('LR', score_lr))

# %%
# importing the necessary package to use the classification algorithm
from sklearn.naive_bayes import GaussianNB
model_nb = GaussianNB()
model_nb.fit(X_train, y_train) #train the model with the training dataset
y_prediction_nb = model_nb.predict(X_test) #pass the testing data to the trained model
pred_5=model_nb.predict(X_test)
con_mat = confusion_matrix(y_test, pred_5)
# checking the accuracy of the algorithm. 
# by comparing predicted output by the model and the actual output
score_nb = metrics.accuracy_score(y_prediction_nb, y_test).round(4)
clf_report = classification_report(y_test, pred_5)
print("---------------------------------")
print('The accuracy of the NB is: {}'.format(score_nb))
print("---------------------------------")
print(f"Confusion Matrix : \n{con_mat}")
print(f"Classification Report : \n{clf_report}")
# save the accuracy score
score.add(('NB', score_nb))

# %%
print("The accuracy scores of different Models Before Smote:")
print("----------------------------------------")
for s in score:
 print(s)

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt

df1 = pd.read_csv("Final1.csv")
dataset=df1.values
dataset
X = dataset[:,0:10]
Y = dataset[:,10]

min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)
#
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)

model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))

model.evaluate(X_test, Y_test)[1]

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
# Out:
# (4134, 10) (886, 10) (886, 10) (4134,) (886,) (886,)
# Epoch 1/100
# 130/130 [==============================] - 1s 4ms/step - loss: 0.6935 - accuracy: 0.4412 - val_loss: 0.6865 - val_accuracy: 0.4255
# Epoch 2/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6886 - accuracy: 0.4458 - val_loss: 0.6825 - val_accuracy: 0.4413
# Epoch 3/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6859 - accuracy: 0.4652 - val_loss: 0.6794 - val_accuracy: 0.4537
# Epoch 4/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6837 - accuracy: 0.4678 - val_loss: 0.6772 - val_accuracy: 0.4729
# Epoch 5/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6817 - accuracy: 0.4867 - val_loss: 0.6745 - val_accuracy: 0.4718
# Epoch 6/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6798 - accuracy: 0.4906 - val_loss: 0.6725 - val_accuracy: 0.4831
# Epoch 7/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6779 - accuracy: 0.4971 - val_loss: 0.6691 - val_accuracy: 0.4774
# Epoch 8/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6759 - accuracy: 0.4959 - val_loss: 0.6665 - val_accuracy: 0.4786
# Epoch 9/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6740 - accuracy: 0.5002 - val_loss: 0.6638 - val_accuracy: 0.4842
# Epoch 10/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6721 - accuracy: 0.5002 - val_loss: 0.6610 - val_accuracy: 0.4853
# Epoch 11/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6701 - accuracy: 0.4978 - val_loss: 0.6586 - val_accuracy: 0.4910
# Epoch 12/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.4981 - val_loss: 0.6564 - val_accuracy: 0.4921
# Epoch 13/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6661 - accuracy: 0.5010 - val_loss: 0.6536 - val_accuracy: 0.4921
# Epoch 14/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6642 - accuracy: 0.5005 - val_loss: 0.6516 - val_accuracy: 0.4989
# Epoch 15/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6621 - accuracy: 0.5102 - val_loss: 0.6484 - val_accuracy: 0.4932
# Epoch 16/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6602 - accuracy: 0.5010 - val_loss: 0.6459 - val_accuracy: 0.4977
# Epoch 17/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6580 - accuracy: 0.5041 - val_loss: 0.6439 - val_accuracy: 0.5000
# Epoch 18/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6560 - accuracy: 0.5082 - val_loss: 0.6413 - val_accuracy: 0.5034
# Epoch 19/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6540 - accuracy: 0.5070 - val_loss: 0.6398 - val_accuracy: 0.5079
# Epoch 20/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6521 - accuracy: 0.5116 - val_loss: 0.6362 - val_accuracy: 0.5034
# Epoch 21/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6502 - accuracy: 0.5128 - val_loss: 0.6345 - val_accuracy: 0.5181
# Epoch 22/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6481 - accuracy: 0.5164 - val_loss: 0.6310 - val_accuracy: 0.5102
# Epoch 23/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6462 - accuracy: 0.5252 - val_loss: 0.6281 - val_accuracy: 0.5135
# Epoch 24/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6441 - accuracy: 0.5290 - val_loss: 0.6250 - val_accuracy: 0.5135
# Epoch 25/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6418 - accuracy: 0.5278 - val_loss: 0.6250 - val_accuracy: 0.5316
# Epoch 26/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6400 - accuracy: 0.5418 - val_loss: 0.6198 - val_accuracy: 0.5192
# Epoch 27/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6372 - accuracy: 0.5365 - val_loss: 0.6204 - val_accuracy: 0.5316
# Epoch 28/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6359 - accuracy: 0.5418 - val_loss: 0.6145 - val_accuracy: 0.5226
# Epoch 29/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6334 - accuracy: 0.5448 - val_loss: 0.6113 - val_accuracy: 0.5260
# Epoch 30/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.5467 - val_loss: 0.6108 - val_accuracy: 0.5305
# Epoch 31/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6297 - accuracy: 0.5493 - val_loss: 0.6061 - val_accuracy: 0.5248
# Epoch 32/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6273 - accuracy: 0.5493 - val_loss: 0.6090 - val_accuracy: 0.5497
# Epoch 33/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6256 - accuracy: 0.5547 - val_loss: 0.6012 - val_accuracy: 0.5237
# Epoch 34/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6234 - accuracy: 0.5508 - val_loss: 0.6006 - val_accuracy: 0.5395
# Epoch 35/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6216 - accuracy: 0.5590 - val_loss: 0.5988 - val_accuracy: 0.5418
# Epoch 36/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6196 - accuracy: 0.5639 - val_loss: 0.5940 - val_accuracy: 0.5237
# Epoch 37/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6180 - accuracy: 0.5593 - val_loss: 0.5939 - val_accuracy: 0.5429
# Epoch 38/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6158 - accuracy: 0.5636 - val_loss: 0.5900 - val_accuracy: 0.5079
# Epoch 39/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6142 - accuracy: 0.5566 - val_loss: 0.5878 - val_accuracy: 0.5226
# Epoch 40/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6127 - accuracy: 0.5617 - val_loss: 0.5866 - val_accuracy: 0.5418
# Epoch 41/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6105 - accuracy: 0.5646 - val_loss: 0.5861 - val_accuracy: 0.5451
# Epoch 42/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6088 - accuracy: 0.5668 - val_loss: 0.5869 - val_accuracy: 0.5598
# Epoch 43/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6069 - accuracy: 0.5670 - val_loss: 0.5839 - val_accuracy: 0.5587
# Epoch 44/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6053 - accuracy: 0.5745 - val_loss: 0.5803 - val_accuracy: 0.5135
# Epoch 45/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6042 - accuracy: 0.5658 - val_loss: 0.5773 - val_accuracy: 0.5395
# Epoch 46/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.6010 - accuracy: 0.5726 - val_loss: 0.5754 - val_accuracy: 0.5463
# Epoch 47/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5996 - accuracy: 0.5709 - val_loss: 0.5745 - val_accuracy: 0.5553
# Epoch 48/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5985 - accuracy: 0.5699 - val_loss: 0.5736 - val_accuracy: 0.5632
# Epoch 49/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5967 - accuracy: 0.5701 - val_loss: 0.5761 - val_accuracy: 0.5722
# Epoch 50/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5952 - accuracy: 0.5772 - val_loss: 0.5695 - val_accuracy: 0.5576
# Epoch 51/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5928 - accuracy: 0.5757 - val_loss: 0.5675 - val_accuracy: 0.5350
# Epoch 52/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5908 - accuracy: 0.5723 - val_loss: 0.5681 - val_accuracy: 0.5722
# Epoch 53/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5898 - accuracy: 0.5762 - val_loss: 0.5651 - val_accuracy: 0.5598
# Epoch 54/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5883 - accuracy: 0.5781 - val_loss: 0.5625 - val_accuracy: 0.5451
# Epoch 55/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5865 - accuracy: 0.5779 - val_loss: 0.5624 - val_accuracy: 0.5632
# Epoch 56/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5845 - accuracy: 0.5762 - val_loss: 0.5614 - val_accuracy: 0.5621
# Epoch 57/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5832 - accuracy: 0.5750 - val_loss: 0.5725 - val_accuracy: 0.5914
# Epoch 58/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5817 - accuracy: 0.5815 - val_loss: 0.5651 - val_accuracy: 0.5745
# Epoch 59/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5806 - accuracy: 0.5866 - val_loss: 0.5570 - val_accuracy: 0.5564
# Epoch 60/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5785 - accuracy: 0.5801 - val_loss: 0.5577 - val_accuracy: 0.5643
# Epoch 61/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5771 - accuracy: 0.5808 - val_loss: 0.5558 - val_accuracy: 0.5598
# Epoch 62/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5755 - accuracy: 0.5798 - val_loss: 0.5534 - val_accuracy: 0.5542
# Epoch 63/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5733 - accuracy: 0.5806 - val_loss: 0.5518 - val_accuracy: 0.5655
# Epoch 64/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5724 - accuracy: 0.5803 - val_loss: 0.5496 - val_accuracy: 0.5643
# Epoch 65/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5708 - accuracy: 0.5806 - val_loss: 0.5473 - val_accuracy: 0.5564
# Epoch 66/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5690 - accuracy: 0.5786 - val_loss: 0.5477 - val_accuracy: 0.5553
# Epoch 67/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5682 - accuracy: 0.5815 - val_loss: 0.5452 - val_accuracy: 0.5553
# Epoch 68/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5668 - accuracy: 0.5825 - val_loss: 0.5501 - val_accuracy: 0.5824
# Epoch 69/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5641 - accuracy: 0.5830 - val_loss: 0.5419 - val_accuracy: 0.5553
# Epoch 70/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5638 - accuracy: 0.5873 - val_loss: 0.5392 - val_accuracy: 0.5576
# Epoch 71/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5614 - accuracy: 0.5808 - val_loss: 0.5385 - val_accuracy: 0.5564
# Epoch 72/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5611 - accuracy: 0.5832 - val_loss: 0.5417 - val_accuracy: 0.5734
# Epoch 73/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5595 - accuracy: 0.5839 - val_loss: 0.5416 - val_accuracy: 0.5756
# Epoch 74/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5577 - accuracy: 0.5917 - val_loss: 0.5340 - val_accuracy: 0.5621
# Epoch 75/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5561 - accuracy: 0.5878 - val_loss: 0.5372 - val_accuracy: 0.5711
# Epoch 76/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5546 - accuracy: 0.5924 - val_loss: 0.5303 - val_accuracy: 0.5655
# Epoch 77/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.5900 - val_loss: 0.5279 - val_accuracy: 0.5598
# Epoch 78/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5518 - accuracy: 0.5881 - val_loss: 0.5275 - val_accuracy: 0.5553
# Epoch 79/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5498 - accuracy: 0.5924 - val_loss: 0.5314 - val_accuracy: 0.5813
# Epoch 80/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5486 - accuracy: 0.5917 - val_loss: 0.5269 - val_accuracy: 0.5756
# Epoch 81/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5472 - accuracy: 0.5934 - val_loss: 0.5217 - val_accuracy: 0.5688
# Epoch 82/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.5926 - val_loss: 0.5282 - val_accuracy: 0.5395
# Epoch 83/100
# 130/130 [==============================] - 0s 3ms/step - loss: 0.5430 - accuracy: 0.5910 - val_loss: 0.5213 - val_accuracy: 0.5576
# Epoch 84/100
#   1/130 [..............................] - ETA: 0s - loss: 0.4148 - accuracy: 0.5312

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-84d24d69b6e4> in <module>
# ----> 1 plt.plot(hist.history['acc'])
#       2 plt.plot(hist.history['val_acc'])
#       3 plt.title('Model accuracy')
#       4 plt.ylabel('Accuracy')
#       5 plt.xlabel('Epoch')
#
# KeyError: 'acc'
